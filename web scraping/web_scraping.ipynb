# %% [markdown]
# #Scraping
# -check sites terms conditions - ex amazon not allow scaping
# -are u going to the DOS attacks - space out your req. dont send continuous like 1000 req per sec
# -keep a check on ur scrappers
# -clean up your data, preprocess raw data
# -configure scraper every time

# %%
#requests - call the server
#beautiful soup - download and scraps website . itd data can be of any format like json
#lxml parser - parses the json data into html form

# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd
from pandas import Series

# %%
url = 'https://www.studentnewsdaily.com/archive/daily-news-article/'

# %%
#step 1 : call the api server using request module
# get req - getting info from server
#post - giving info to server ex input in forms
result = requests.get(url)

# %%
# print(result.content)
soup = BeautifulSoup(result.content, 'lxml')

# %%
print(soup)  #prints clean html
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <title>Daily News Article  </title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#000000" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Nunito:400,400i,600,600i,700,700i%7cPermanent+Marker" rel="stylesheet"/>
# <!-- Google tag (gtag.js) -->
# ...

# %% [markdown]
# to fetch some particular section of web, u can fetch by using its/ that div's class name

# %%
content = soup.findAll('div')
# print(content)
print(len(content))
# Out:
# 69

# %%
content = soup.findAll('section')

# %%
# print(content)

# %%
summary = content[1].find(class_='col-md-10 col-lg-10 col-xl-10')
print(summary)
# Out:
# <div class="col-md-10 col-lg-10 col-xl-10">
# <article>
# <!-- <h3>Full Archive</h3> -->
# <h4>May 2025</h4>
# <p style="margin-bottom: 2px; padding: 0;">
#                 5/29/2025 - <a href="https://www.studentnewsdaily.com/daily-news-article/us-armys-250th-anniversary-grand-military-parade-and-celebration-on-june-14/">US Army’s 250th Anniversary Grand Military Parade and Celebration on June 14</a> - America250.org, Army.mil                                </p>
# <p style="margin-bottom: 2px; padding: 0;">
#                 5/23/2025 - <a href="https://www.studentnewsdaily.com/daily-news-article/memorial-day-2025/">Memorial Day 2025</a> </p>
# <p style="margin-bottom: 2px; padding: 0;">
#                 5/23/2025 - <a href="https://www.studentnewsdaily.com/daily-news-article/harvard-blocked-by-dhs-from-enrolling-international-students/">Harvard blocked by DHS from enrolling international students</a> - CNBC                                </p>
# ...

# %%
l = (summary.findAll('h4'))

# %%
series = [ele.get_text() for ele in l]

# %%
print(series)
# Out:
# ['May 2025', 'April 2025', 'March 2025', 'February 2025', 'January 2025', 'December 2024', 'November 2024', 'October 2024', 'September 2024', 'August 2024', 'September 2021', 'June 2021', 'May 2021', 'April 2021', 'March 2021', 'February 2021', 'January 2021', 'December 2020', 'November 2020', 'October 2020', 'September 2020', 'May 2020', 'April 2020', 'March 2020', 'February 2020', 'January 2020', 'December 2019', 'November 2019', 'October 2019', 'September 2019', 'May 2019', 'April 2019', 'March 2019', 'February 2019']
